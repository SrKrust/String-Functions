# %% [markdown]
# ## String functions

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # 1.split()

# %%
a = "manali,sumit,yash" #create a string

# %%
b = a. split(',') #it separated string by any separator and returns the string in the form of list.

# %%
print(b)
# Out:
# ['manali', 'sumit', 'yash']

# %%
b = "manali%sumit%yash%isha"

# %%
c = b.split('%')

# %%
print(c)
# Out:
# ['manali', 'sumit', 'yash', 'isha']

# %% [markdown]
# # 2.splitlines()

# %%
a = "Hello\nGood morning everyone" #create a string

# %%
b = a.splitlines() #it break the line using "\n" and returns the string in the form of list.

# %%
print(b)
# Out:
# ['Hello', 'Good morning everyone']

# %%
i = "We are learning python.It is easy to code"

# %%
m =i.splitlines() #we break the line only using \n. Another separator is not allowed.

# %%
print(m)
# Out:
# ['We are learning python.It is easy to code']

# %% [markdown]
# # 3.startswith()

# %%
s = "Comments can be used to explain Python code"

# %%
t =s.startswith("Comments")
#If the string is starting with "Comments" then it will return the true otherwise it will return false.

# %%
print(t)
# Out:
# True

# %%
s = "Comments can be used to explain Python code"

# %%
t =s.startswith("can")
#String is not starting "Comments" so it return false.

# %%
print(t)
# Out:
# False

# %%
s = "Comments can be used to explain Python code"

# %%
t =s.startswith("Comments can")

# %%
print(t)
# Out:
# True

# %% [markdown]
# # 4.strip()

# %%
a = "   nice day   " #create a string

# %%
x = a.strip()  
#1.strip() remves any leading(spaces at beginning) & trailing(spaces at the end) characters
#2.removes also special characters from the string

# %%
print("Have", "a" ,x)
# Out:
# Have a nice day

# %%
g = ",,,,,,,good morning!!!!! "

# %%
h = g.strip(", !")

# %%
print(h)
# Out:
# good morning

# %% [markdown]
# # 5.swapcase()

# %%
sen = "Hi MY naMe Is MANALI" #create a string

# %%
a = sen.swapcase() #In this function lower case becomes uppercase and uppercase becomes lowercase.

# %%
print(a)
# Out:
# hI my NAmE iS manali

# %%
a = "BanAna,APPle"

# %%
b = a.swapcase()

# %%
print(b)
# Out:
# bANaNA,appLE

# %% [markdown]
# # 6.title()

# %%
a = "We are learning python" #string

# %%
b = a.title() #convert first character of each word into a upper case.

# %%
print(b)
# Out:
# We Are Learning Python

# %%
a = "cat,dog,rabbit,tiger"

# %%
b = a.title()

# %%
print(b)
# Out:
# Cat,Dog,Rabbit,Tiger

# %% [markdown]
# # 7.traslate()

# %%
dict = {a:89} #create a dict

# %%
a = "Hello Sumit"

# %%
print(a.translate(dict))  #some specified characters are replaced with character described in a dict.
# Out:
# Hello Sumit

# %%
a = {"a":[1.23],1:23}

# %%
b = "Welcome to Pune"

# %%
print(b.translate(a))
# Out:
# Welcome to Pune

# %% [markdown]
# # 8.upper()

# %%
s = "give me some chocolates"

# %%
a =s.upper() #it converts whole string into upper case

# %%
print(a)
# Out:
# GIVE ME SOME CHOCOLATES

# %% [markdown]
# # 9.zfill()

# %%
a = "too much rain in pune"

# %%
print(a.zfill(25)) #it fills the string with specified number of 0 at the beginning of the string.
# Out:
# 0000too much rain in pune

# %%
b = "Hello everyone"

# %%
print(b.zfill(30))
# Out:
# 0000000000000000Hello everyone
